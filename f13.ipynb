# %% [markdown]
# # range(start,stop,step)

# %%
for a in range(1,51,1):
    print(a,"f")
# Out:
# 1 f
# 2 f
# 3 f
# 4 f
# 5 f
# 6 f
# 7 f
# 8 f
# 9 f
# 10 f
# 11 f
# 12 f
# 13 f
# 14 f
# 15 f
# 16 f
# 17 f
# 18 f
# 19 f
# 20 f
# 21 f
# 22 f
# 23 f
# 24 f
# 25 f
# 26 f
# 27 f
# 28 f
# 29 f
# 30 f
# 31 f
# 32 f
# 33 f
# 34 f
# 35 f
# 36 f
# 37 f
# 38 f
# 39 f
# 40 f
# 41 f
# 42 f
# 43 f
# 44 f
# 45 f
# 46 f
# 47 f
# 48 f
# 49 f
# 50 f

# %%
for a in range(1,11,1):
    print("2 X ",a, "=",2*a)
# Out:
# 2 X  1 = 2
# 2 X  2 = 4
# 2 X  3 = 6
# 2 X  4 = 8
# 2 X  5 = 10
# 2 X  6 = 12
# 2 X  7 = 14
# 2 X  8 = 16
# 2 X  9 = 18
# 2 X  10 = 20

# %%
for i in range(1,1001,1):
    print("Sorry")
# Out:
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# Sorry
# ...
